# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("D:/downloads/myexcel - myexcel.csv.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.shape
# Out:
# (458, 9)

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
#1.How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
aj=pd.DataFrame(df.groupby(['Team'],as_index=False)['Number'].sum().sort_values(by="Team"))
aj
# Out:
#                       Team  Number
# 0            Atlanta Hawks     285
# 1           Boston Celtics     478
# 2            Brooklyn Nets     274
# 3        Charlotte Hornets     257
# 4            Chicago Bulls     288
# 5      Cleveland Cavaliers     217
# 6         Dallas Mavericks     300
# 7           Denver Nuggets     229
# 8          Detroit Pistons     259
# 9    Golden State Warriors     313
# 10         Houston Rockets     220
# 11          Indiana Pacers     284
# 12    Los Angeles Clippers     293
# 13      Los Angeles Lakers     241
# 14       Memphis Grizzlies     280
# 15              Miami Heat     157
# 16         Milwaukee Bucks     320
# 17  Minnesota Timberwolves     274
# 18    New Orleans Pelicans     323
# 19         New York Knicks     212
# 20   Oklahoma City Thunder     210
# 21           Orlando Magic     230
# 22      Philadelphia 76ers     271
# 23            Phoenix Suns     232
# 24  Portland Trail Blazers     240
# 25        Sacramento Kings     254
# ...

# %%
total_sum=aj["Number"].sum()
total_sum
# Out:
# 8113

# %%
aj["Percentage"]=aj["Number"]*100/total_sum

# %%
aj
# Out:
#                       Team  Number  Percentage
# 0            Atlanta Hawks     285    3.512881
# 1           Boston Celtics     478    5.891779
# 2            Brooklyn Nets     274    3.377296
# 3        Charlotte Hornets     257    3.167755
# 4            Chicago Bulls     288    3.549858
# 5      Cleveland Cavaliers     217    2.674720
# 6         Dallas Mavericks     300    3.697769
# 7           Denver Nuggets     229    2.822630
# 8          Detroit Pistons     259    3.192407
# 9    Golden State Warriors     313    3.858006
# 10         Houston Rockets     220    2.711697
# 11          Indiana Pacers     284    3.500555
# 12    Los Angeles Clippers     293    3.611488
# 13      Los Angeles Lakers     241    2.970541
# 14       Memphis Grizzlies     280    3.451251
# 15              Miami Heat     157    1.935166
# 16         Milwaukee Bucks     320    3.944287
# 17  Minnesota Timberwolves     274    3.377296
# 18    New Orleans Pelicans     323    3.981265
# ...

# %%
#2.Segregate the employees w.r.t different positions.

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
pd.set_option('display.max_colwidth', None)
ak=pd.DataFrame(df.groupby("Position",as_index=False)["Name"].apply(lambda x: ",".join(x)))
ak
# Out:
#   Position  \
# 0        C
# 1       PF
# 2       PG
# 3       SF
# 4       SG
#
# ...

# %%
#3.Find from which age group most of the employees belong to.

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
ab=df["Age"].value_counts().sort_values()
ab
# Out:
# Age
# 19     2
# 39     2
# 40     3
# 38     4
# 37     4
# 35     9
# 36    10
# 34    10
# 32    13
# 33    14
# 21    19
# 20    19
# 31    22
# 22    26
# 29    28
# 30    31
# 28    31
# 26    36
# 23    41
# 27    41
# 25    46
# 24    47
# Name: count, dtype: int64

# %%
max=ab.idxmax()
print("age group most of the employees belong to is %d "%max)
# Out:
# age group most of the employees belong to is 24

# %%
#4.Find out under which team and position, spending in terms of salary is high.

# %%
ac=pd.DataFrame(df.groupby(["Team","Position"],as_index=False)['Salary'].sum().sort_values(by="Salary"))
ac
# Out:
#                    Team Position      Salary
# 107       Orlando Magic       SF    845059.0
# 74           Miami Heat        C    981348.0
# 125    Sacramento Kings       PF   1370152.0
# 112  Philadelphia 76ers       SF   1845059.0
# 38       Denver Nuggets       SG   2790245.0
# ..                  ...      ...         ...
# 37       Denver Nuggets       SF  27982771.0
# 116        Phoenix Suns       PG  28002998.0
# 53      Houston Rockets       SG  28122883.0
# 75           Miami Heat       PF  31538671.0
# 67   Los Angeles Lakers       SF  31866445.0
#
# [149 rows x 3 columns]

# %%
ac["Salary"].max()
# Out:
# 31866445.0

# %%
ac.loc[ac["Salary"]==31866445.0,["Team","Position"]]
# Out:
#                   Team Position
# 67  Los Angeles Lakers       SF

# %%
5.Find if there is any correlation between age and salary , represent it visually.
Before doing the above questions,perform pre processing of the dataset. Also, the column height is having incorrect data, changing the data of that particular column with any random numbers between 150 and 180.
After completing the project upload your jupyter notebook ipynb file and the dataset in the github and share the link.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df["Height"]
# Out:
# 0      06-Feb
# 1      06-Jun
# 2      06-May
# 3      06-May
# 4      06-Oct
#         ...
# 453    06-Mar
# 454    06-Jan
# 455    07-Mar
# 456       7-0
# 457    07-Mar
# Name: Height, Length: 458, dtype: object

# %%
import random

# %%
for i in range(len(df)):
    df.loc[i,"Height"]=random.randint(150,180)
df["Height"]
# Out:
# 0      174
# 1      171
# 2      165
# 3      166
# 4      170
#       ...
# 453    154
# 454    154
# 455    153
# 456    178
# 457    175
# Name: Height, Length: 458, dtype: int64

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     174     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     171     235
# 2     John Holland  Boston Celtics      30       SG   27     165     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     166     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     170     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     154     203
# 454      Raul Neto       Utah Jazz      25       PG   24     154     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     153     256
# 456    Jeff Withey       Utah Jazz      24        C   26     178     231
# 457       Priyanka       Utah Jazz      34        C   25     175     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
x="Age"
y="Salary"
plt.scatter(df["Age"],df["Salary"])
plt.xlabel(x)
plt.ylabel(y)
plt.show()

# %%
corr=df[["Age","Salary"]].corr()
sns.heatmap(corr,annot=True,cmap="viridis")
plt.title('Correlation between Age and salary')
plt.show()
